# %% [markdown]
# <a href="https://colab.research.google.com/github/Mileidy06/PrograIII-semi26/blob/main/miPrimerProyecto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
saludo = "Hola chicos de progra III"
print(saludo, "Primera letra del saludo", saludo[0:4])

num1 =5.25
print(num1)

boole = True
print(boole)
# Out:
# Hola chicos de progra III Primera letra del saludo Hola
# 5.25
# True

# %%
print("sumar dos numeros: ")
num1 = input("Num1: ")
num2 = input("Num2: ")
respuesta = float (num1) + float (num2)

print(type(num1), type (num2), type (respuesta))
print("respuesta: ", respuesta)
respuesta ="Suma completa"
print (respuesta, type(respuesta))
# Out:
# sumar dos numeros:
# Num1: 1
# Num2: 5
# <class 'str'> <class 'str'> <class 'float'>
# respuesta:  6.0
# Suma completa <class 'str'>

# %%
print("restar dos numeros: ")
num1 = input("Num1: ")
num2 = input("Num2: ")
respuesta = float (num1) - float (num2)

print("respuesta: ", respuesta)
# Out:
# restar dos numeros:
# Num1: 3
# Num2: 2
# respuesta:  1.0

# %%
print("multiplicar dos numeros: ")
num1 = input("Num1: ")
num2 = input("Num2: ")
respuesta = float (num1) * float(num2)

print("respuesta: ", respuesta)
# Out:
# multiplicar dos numeros:
# Num1: 2
# Num2: 2
# respuesta:  4.0

# %%
print("Dividir dos numeros: ")
num1 = input("Num1: ")
num2 = input("Num2: ")
respuesta = float (num1) / float(num2)

print("respuesta: ", respuesta)
# Out:
# Dividir dos numeros:
# Num1: 10
# Num2: 2
# respuesta:  5.0

# %%
saludo = "Hola chicos de progra"
print("Primer Elemento de la cadena", saludo[0])
print("Rango de una cadena", saludo[0:4])
print("Ultimo elemento", saludo[-1])
print("Ultimo elemento", saludo[len(saludo)-1])
print("valores en medio, sin especificar ultimo valor", saludo[5:])
print ("Sin valor al inicio", saludo [:4])
print ("Contar del final", saludo [5:-1])
# Out:
# Primer Elemento de la cadena H
# Rango de una cadena Hola
# Ultimo elemento a
# Ultimo elemento a
# valores en medio, sin especificar ultimo valor chicos de progra
# Sin valor al inicio Hola
# Contar del final chicos de progr

# %% [markdown]
# Funciones de Python

# %%
def suma(num1, num2):
  respuesta = float(num1) + float(num2)
  return respuesta

# %%
def resta (num1, num2):
  respuesta = float(num1) - float(num2)
  return respuesta

# %%
num1 = input("Num 1: ")
num2 = input("Num 2: ")
print("La suma: ",suma(num1, num2))
print("La Resta: ",resta(num1, num2))
# Out:
# Num 1: 4
# Num 2: 5
# La suma:  9.0
# La Resta:  -1.0

# %%
def convrCaf(celcius):
  return float(celcius)*9/5 + 32

# %%
c = input("Grados Celcius: ")
print("Grados Ferenheit:", convrCaf(c))
# Out:
# Grados Celcius: 15
# Grados Ferenheit: 59.0

# %%
def converFac(f):
  return (float(f)-32) *5/9

# %%
f = input("Farenheit: ")
print("Grados Celcius:", converFac(f))
# Out:
# Farenheit: 15
# Grados Celcius: -9.444444444444445

# %%
def converCak(c):
  return float(c) + 273.15

# %%
c = input("Celcius: ")
print("Grados Kelvin:", converCak(c))
# Out:
# Celcius: 14
# Grados Kelvin: 287.15

# %%
convertir = lambda c: float(c)*9/5 + 32

# %%
c = float(input("Grados Celcius: "))
print("Grados Ferenheit:", convertir(c))
# Out:
# Grados Celcius: 15
# Grados Ferenheit: 59.0
